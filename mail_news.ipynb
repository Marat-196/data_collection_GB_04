# %%
import pandas as pd

# %%
df = pd.read_csv('mail_news.csv')
df.head()
# Out:
#                                                 name  \
# 0  ['Лавров прокомментировал использование Украин...
# 1  ['СМИ: граждан Швеции, Норвегии и Финляндии пр...
# 2  ['Песков: на применение ВСУ неядерных ракет во...
# 3  ['Политолог: Россия поразит объекты ВС США в о...
# 4  ['Шесть стран Европы обвинили Россию в активиз...
#
#                                                title         source  \
# 0  ['РИО-ДЕ-ЖАНЕЙРО, 19 ноя\xa0— РИА Новости. Исп...  © РИА Новости
# 1  ['На\xa0фоне эскалации конфликта в\xa0Восточно...   Новости Mail
# 2  ['Пресс-секретарь президента\xa0РФ Дмитрий Пес...   Новости Mail
# 3  ['Политолог Юрий Светлов назвал возможную цель...   Новости Mail
# 4  ['Министры иностранных дел шести стран Европы ...            РБК
#
#              url_source    tag_news
# 0     http://www.ria.ru  Саммит G20
# 1  https://news.mail.ru  Саммит G20
# 2  https://news.mail.ru  Саммит G20
# 3  https://news.mail.ru  Саммит G20
# 4   https://www.rbc.ru/  Саммит G20

# %%
df.describe()
# Out:
#                                                      name  \
# count                                                  11
# unique                                                 10
# top     ['Шесть стран Европы обвинили Россию в активиз...
# freq                                                    2
#
#                                                     title        source  \
# count                                                  11            10
# unique                                                 10             5
# top     ['Министры иностранных дел шести стран Европы ...  Новости Mail
# freq                                                    2             4
#
#                   url_source    tag_news
# count                     10           9
# unique                     5           1
# top     https://news.mail.ru  Саммит G20
# freq                       4           9
